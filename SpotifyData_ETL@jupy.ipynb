# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager=SpotifyClientCredentials(client_id='fb8ef6905fc84f289cbe982c9f2911cf',client_secret='069109da05a340978dd20e0629740a40')
#this is for authentication of API keys

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager) #this is for authorization to access the Spotify's data using object sp

# %%
playlst_lnk='https://open.spotify.com/playlist/37i9dQZEVXbLZ52XmnySJg' #This link takes to top 50 indian songs

# %%
playlst_URI=playlst_lnk.split('/')[-1]   #Retrieving URI to pull tracks using sp.playlist_tracks()

# %%
data_tracks=sp.playlist_tracks(playlst_URI)
print(type(data_tracks))
data_tracks
# Out:
# <class 'dict'>
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbLZ52XmnySJg/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-10-06T12:28:01Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
# ...

# %%
#data_tracks['items'][0]
data_tracks['items']
# Out:
# [{'added_at': '2024-10-06T12:28:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
# ...

# %%
album_list=[]                             #Data related to album is stored in a list and later converts into a DataFrame
for row in data_tracks['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    release_date=row['track']['album']['release_date']
    album_url=row['track']['album']['external_urls']['spotify']
    album_tracks=row['track']['album']['total_tracks']
    album_dict={'album_id':row['track']['album']['id'],'album_name':row['track']['album']['name'],'release_date':row['track']['album']['release_date'],'album_url':row['track']['album']['external_urls']['spotify'],'album_tracks':row['track']['album']['total_tracks']}
    album_list.append(album_dict)
print(album_list)
# Out:
# [{'album_id': '0upenH0uUT36nBbVM5mQhW', 'album_name': 'Jo Tum Mere Ho', 'release_date': '2024-08-02', 'album_url': 'https://open.spotify.com/album/0upenH0uUT36nBbVM5mQhW', 'album_tracks': 1}, {'album_id': '2P2orRpVU0F2Z1HGTi7AiS', 'album_name': 'Aaj Ki Raat (From "Stree 2")', 'release_date': '2024-07-24', 'album_url': 'https://open.spotify.com/album/2P2orRpVU0F2Z1HGTi7AiS', 'album_tracks': 1}, {'album_id': '5KF4xCxDD8ip003hoatFT9', 'album_name': 'GLORY', 'release_date': '2024-08-26', 'album_url': 'https://open.spotify.com/album/5KF4xCxDD8ip003hoatFT9', 'album_tracks': 18}, {'album_id': '77bk7awXNSGEQkZTcTp2Gj', 'album_name': 'Chuttamalle (From "Devara Part 1")', 'release_date': '2024-08-05', 'album_url': 'https://open.spotify.com/album/77bk7awXNSGEQkZTcTp2Gj', 'album_tracks': 1}, {'album_id': '7tCxLHdbch1AEkuv2EbLQc', 'album_name': 'Aayi Nai (From "Stree 2")', 'release_date': '2024-08-01', 'album_url': 'https://open.spotify.com/album/7tCxLHdbch1AEkuv2EbLQc', 'album_tracks': 1}, {'alb
# ...

# %%
import pandas as pd
album_df=pd.DataFrame(album_list)
album_df.head()
# Out:
#                  album_id                          album_name release_date  \
# 0  0upenH0uUT36nBbVM5mQhW                      Jo Tum Mere Ho   2024-08-02
# 1  2P2orRpVU0F2Z1HGTi7AiS        Aaj Ki Raat (From "Stree 2")   2024-07-24
# 2  5KF4xCxDD8ip003hoatFT9                               GLORY   2024-08-26
# 3  77bk7awXNSGEQkZTcTp2Gj  Chuttamalle (From "Devara Part 1")   2024-08-05
# 4  7tCxLHdbch1AEkuv2EbLQc           Aayi Nai (From "Stree 2")   2024-08-01
#
#                                            album_url  album_tracks
# 0  https://open.spotify.com/album/0upenH0uUT36nBb...             1
# 1  https://open.spotify.com/album/2P2orRpVU0F2Z1H...             1
# 2  https://open.spotify.com/album/5KF4xCxDD8ip003...            18
# 3  https://open.spotify.com/album/77bk7awXNSGEQkZ...             1
# 4  https://open.spotify.com/album/7tCxLHdbch1AEku...             1

# %%
artist_list=[]                      # Data related to artist is stored in a list and later converts into a DataFrame
for row in data_tracks['items']:     # As the artist deatails are stored in nested dictionary which is in a list, row.items gives the list of
    for key,val in row.items():       # elements in the row.items where artists is one of the element(which is a dictionary)
        if key=='track':
            for artist in val['artists']:
                artist_dict={'artist_id':artist['id'],'artist_url':artist['href'],'artist_name':artist['name']}
                artist_list.append(artist_dict)
artist_list
artist_df=pd.DataFrame(artist_list)
artist_df.head()
# Out:
#                 artist_id                                         artist_url  \
# 0  4gdMJYnopf2nEUcanAwstx  https://api.spotify.com/v1/artists/4gdMJYnopf2...
# 1  1mBydYMVBECdDmMfE2sEUO  https://api.spotify.com/v1/artists/1mBydYMVBEC...
# 2  4ojkMVHjuDZgDXSJy5qs2h  https://api.spotify.com/v1/artists/4ojkMVHjuDZ...
# 3  0NErdIJtuKBjtxKmlqaWdj  https://api.spotify.com/v1/artists/0NErdIJtuKB...
# 4  2fMqTqiTxUDlmcOEPaQSsx  https://api.spotify.com/v1/artists/2fMqTqiTxUD...
#
#             artist_name
# 0             Anuv Jain
# 1          Sachin-Jigar
# 2     Madhubanti Bagchi
# 3           Divya Kumar
# 4  Amitabh Bhattacharya

# %%
song_list=[]                        # Data related to album is stored in a list and later converts into a DataFrame
for row in data_tracks['items']:
    song_id=row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    song_url=row['track']['external_urls']['spotify']
    album_id=row['track']['album']['id']
    artist_id=row['track']['artists'][0]['id']
    song_dict={'song_id':song_id,'song_name':song_name,'song_duration':song_duration,'song_popularity':song_popularity,'song_added':song_added,'song_url':song_url,'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_dict)
song_list
# Out:
# [{'song_id': '0eCajpR75pDW0r64U6hP2x',
#   'song_name': 'Jo Tum Mere Ho',
#   'song_duration': 251813,
#   'song_popularity': 82,
#   'song_added': '2024-09-30T12:13:55Z',
#   'song_url': 'https://open.spotify.com/track/0eCajpR75pDW0r64U6hP2x',
#   'album_id': '0upenH0uUT36nBbVM5mQhW',
#   'artist_id': '4gdMJYnopf2nEUcanAwstx'},
#  {'song_id': '7EFfeGN5U0zm9C6KpOeNBH',
#   'song_name': 'Aaj Ki Raat (From "Stree 2")',
#   'song_duration': 228620,
#   'song_popularity': 66,
#   'song_added': '2024-09-30T12:13:55Z',
#   'song_url': 'https://open.spotify.com/track/7EFfeGN5U0zm9C6KpOeNBH',
#   'album_id': '3UFJUJXBdfDRd2qRZ9ijyn',
#   'artist_id': '1mBydYMVBECdDmMfE2sEUO'},
#  {'song_id': '2TnmSSPkcPdHYYw2Lu84C1',
#   'song_name': 'Aayi Nai (From "Stree 2")',
#   'song_duration': 178780,
#   'song_popularity': 63,
#   'song_added': '2024-09-30T12:13:55Z',
#   'song_url': 'https://open.spotify.com/track/2TnmSSPkcPdHYYw2Lu84C1',
#   'album_id': '2zoS9X4ZOstatr5qrdc2V7',
# ...

# %%
song_df=pd.DataFrame.from_dict(song_list)
song_df.head
# Out:
# <bound method NDFrame.head of                    song_id                                          song_name  \
# 0   0eCajpR75pDW0r64U6hP2x                                     Jo Tum Mere Ho
# 1   7EFfeGN5U0zm9C6KpOeNBH                       Aaj Ki Raat (From "Stree 2")
# 2   2TnmSSPkcPdHYYw2Lu84C1                          Aayi Nai (From "Stree 2")
# 3   1bxzr3JK05fMTcweGAZUHp                 Chuttamalle (From "Devara Part 1")
# 4   5zCnGtCl5Ac5zlFHXaZmhy                     Sajni (From "Laapataa Ladies")
# 5   1hlbywc8Jhl1FFqJxAMabE                                               Ishq
# 6   7KB0zREYCrQU3refE5x0M3                     Manasilaayo (From "Vettaiyan")
# 7   0TL0LFcwIBF5eX7arDIKxY                                               Husn
# 8   78BWCd70D1X6LMkDZm1UoF                                        Millionaire
# 9   1WaqQIJ0iENGWZ1QmYvYNK                      Tauba Tauba (From "Bad Newz")
# 10  6BGZePfo75ysi4IR2jlFR0                             Tumhare Hi Rahenge Hum
# ...

# %%
song_df[song_df.duplicated(subset=['song_id'],keep='first')]
album_df[album_df.duplicated(subset=['album_id'],keep='first')]
# Out:
#                   album_id     album_name release_date  \
# 47  3IbKcMtNRze5t0ANwdp45H  Desi Kalakaar   2014-09-26
#
#                                             album_url  album_tracks
# 47  https://open.spotify.com/album/3IbKcMtNRze5t0A...             8

# %%
artist_df.drop_duplicates(subset=['artist_id'],inplace=True)  # Removing duplicate artist_id's and checked for album_id and song_id

# %%
album_df['release_date']=pd.to_datetime(album_df['release_date'],format='mixed',dayfirst=True) # Converted release_date into datetime format
album_df.info()         # Earlier it used to be in object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   album_name    50 non-null     object
#  2   release_date  50 non-null     datetime64[ns]
#  3   album_url     50 non-null     object
#  4   album_tracks  50 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
album_df['release_date']=pd.to_datetime(album_df['release_date'],format='mixed',dayfirst=True)

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2   song_duration    50 non-null     int64
#  3   song_popularity  50 non-null     int64
#  4   song_added       50 non-null     datetime64[ns, UTC]
#  5   song_url         50 non-null     object
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
type(artist_df['artist_id'][0])
# Out:
# str

# %%
album_df.to_csv('album_data_index.csv') # Made index=False, in csv files the index row is not needed
artist_df.to_csv('artist_data.csv',index=False)
song_df.to_csv('song_data.csv',index=False)
